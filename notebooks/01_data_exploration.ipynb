# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("atlas-higgs-challenge-2014-v2.csv")

# %%
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (818238, 35)
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818238 entries, 0 to 818237
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      818238 non-null  int64
#  1   DER_mass_MMC                 818238 non-null  float64
#  2   DER_mass_transverse_met_lep  818238 non-null  float64
#  3   DER_mass_vis                 818238 non-null  float64
#  4   DER_pt_h                     818238 non-null  float64
#  5   DER_deltaeta_jet_jet         818238 non-null  float64
#  6   DER_mass_jet_jet             818238 non-null  float64
#  7   DER_prodeta_jet_jet          818238 non-null  float64
#  8   DER_deltar_tau_lep           818238 non-null  float64
#  9   DER_pt_tot                   818238 non-null  float64
#  10  DER_sum_pt                   818238 non-null  float64
#  11  DER_pt_ratio_lep_tau         818238 non-null  float64
# ...

# %%
df.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  818238.000000  818238.000000                818238.000000
# mean   509118.500000     -48.819019                    49.252714
# std    236205.109119     406.118397                    35.378609
# min    100000.000000    -999.000000                     0.000000
# 25%    304559.250000      78.166000                    19.304000
# 50%    509118.500000     105.061000                    46.484000
# 75%    713677.750000     130.730000                    73.620000
# max    918237.000000    1949.261000                   968.669000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  818238.000000  818238.000000         818238.000000     818238.000000
# mean       81.140561      57.849524           -707.740880       -600.191191
# std        40.582708      63.411938            454.793899        658.724040
# ...

# %%
print("NaN values per column:")
df.isnull().sum().sort_values(ascending=False)
# Out:
# NaN values per column:
# EventId                        0
# PRI_jet_leading_phi            0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_subleading_pt          0
# PRI_lep_eta                    0
# PRI_jet_subleading_eta         0
# PRI_jet_subleading_phi         0
# PRI_jet_all_pt                 0
# Weight                         0
# Label                          0
# KaggleSet                      0
# PRI_lep_phi                    0
# PRI_lep_pt                     0
# DER_mass_MMC                   0
# DER_deltar_tau_lep             0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_pt_tot                     0
# ...

# %%
print("Encoded missing values (-999) per column:")
(df == -999).sum().sort_values(ascending=False)
# Out:
# Encoded missing values (-999) per column:
# PRI_jet_subleading_eta         580253
# DER_lep_eta_centrality         580253
# DER_deltaeta_jet_jet           580253
# DER_mass_jet_jet               580253
# DER_prodeta_jet_jet            580253
# PRI_jet_subleading_phi         580253
# PRI_jet_subleading_pt          580253
# PRI_jet_leading_pt             327371
# PRI_jet_leading_eta            327371
# PRI_jet_leading_phi            327371
# DER_mass_MMC                   124602
# PRI_met_sumet                       0
# PRI_jet_num                         0
# EventId                             0
# PRI_met                             0
# PRI_jet_all_pt                      0
# Weight                              0
# Label                               0
# KaggleSet                           0
# PRI_met_phi                         0
# PRI_lep_pt                          0
# PRI_lep_phi                         0
# PRI_lep_eta                         0
# ...

# %% [markdown]
# ### Handling Missing Values
# The Higgs dataset does not contain conventional missing values (NaN). Instead, missing measurements are encoded using the value −999, following standard practice in particle physics datasets. These encoded missing values occur primarily in jet-related features, such as jet momentum, angular separation, and invariant mass. This reflects the physical nature of the data, as not all collision events produce jets, making certain measurements undefined.
#
# An analysis of the dataset revealed that several jet-dependent features contain a large number of −999 values, while many core kinematic variables contain none. To ensure these encoded values do not bias model training, all occurrences of −999 will be replaced with NaN and subsequently imputed using the median value of each feature. Median imputation was chosen due to its robustness against skewed distributions and outliers, which are common in high-energy physics data.
#
# This preprocessing step ensures that all models receive complete numerical inputs while preserving the underlying physical structure of the dataset.

# %%
target_col = "Label"  
class_counts = df[target_col].value_counts()

plt.figure(figsize=(6, 4))
class_counts.plot(kind="bar")
plt.title("Class Distribution (Signal vs Background)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.tight_layout()
plt.savefig("results/figures/class_distribution.png")
plt.show()

# %%
imbalance_ratio = class_counts / class_counts.sum()
imbalance_ratio
# Out:
# Label
# b    0.658339
# s    0.341661
# Name: count, dtype: float64

# %%
numeric_df = df.select_dtypes(include=[np.number])

numeric_df.iloc[:, :5].hist(figsize=(12, 6), bins=50)
plt.suptitle("Sample Feature Distributions")
plt.tight_layout()
plt.show()

# %%
sample_features = numeric_df.sample(15, axis=1)

plt.figure(figsize=(12, 10))
sns.heatmap(sample_features.corr(), cmap="coolwarm", linewidths=0.1)
plt.title("Correlation Heatmap (Random Feature Subset)")
plt.tight_layout()
plt.savefig("results/figures/correlation_heatmap.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Correlation Analysis
# Only numerical input features were considered for correlation analysis, as correlation measures linear relationships between continuous variables. The heatmap shows that several features exhibit moderate correlations, indicating complex dependencies between physics-derived variables. This motivates the use of tree-based models such as Random Forest and XGBoost, which are well-suited to capture non-linear feature interactions.
